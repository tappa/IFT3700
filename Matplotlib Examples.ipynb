# %%
#"%matplotlib inline" is needed for plotting between cells 
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from loaders import Mnist
mnist = Mnist()

# %%
x = range(100)
y = np.random.randint(0,1000, 100)

plt.plot(x, y)
plt.show()

# %%
img = mnist.train.x[0].reshape(28, 28)
plt.imshow(img, cmap='gray')
plt.title('The first training element')
plt.axis('off')
plt.show()

# %%
intensity = sorted(img.flatten(), reverse=True)
plt.plot(intensity)
plt.show()
